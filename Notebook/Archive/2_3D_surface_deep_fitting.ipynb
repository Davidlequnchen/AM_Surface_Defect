# %% [markdown]
# # Point cloud based surface defect detection and localisation
#
# ### Author: Chen Lequn
# #### Initial commit: 13 Jan, 2021
#
# ## Project description and objectives:
# - Preprocessing the point cloud data:
# 1. data standarisation - centered at zero coordinate;
# 2. Data labeling: add a fourth dimension to the dataset - marking all the points to "non-defective (flat)"; "machining (bulge)"; "AM repair (dent)"
# - 3D shape fitting feature extraction:
# 1. calculating surface normal vector and principle curvatures.
# 2. Methdologies (candidate): PCA, Jet approximation, DeepFit Network (based on PointNet, ECCV 2020)
# - Segmentation/Classification:
# 1. Automatic point cloud segmentation based on PointNet
# 2. Explore various point cloud classification/segmentation algorithms from recent years 2017-2021 CVPR/IROS
#
# ## **Notebook 2: point cloud shape fitting and feature extraction analysis**
#
# ## Introduction
#
# This notebook aims to estimate normal vectors and principal curvatures from 3D point clouds using classic PCA and Jet fitting methods as well as recent DeepFit method.
#
#
# Surface normals and curvatures are a very important properties in shape analysis and are widely used in different fields like computer graphics, computer vision and more.
#
# Such features are useful for noise reduction, point cloud segmentation, and classification.
#
#
# ### Reference:
# - **DeepFit(ECCV 2020)** Network: 3D surface fitting https://github.com/sitzikbs/DeepFit
# - **Nesti-Net**: Normal Estimation for Unstructured 3D Point Clouds using Convolutional Neural Networks: https://github.com/sitzikbs/Nesti-Net#nesti-net-normal-estimation-for-unstructured-3d-point-clouds-using-convolutional-neural-networks
# * [PCL normal estimation using PCA](http://pointclouds.org/documentation/tutorials/normal_estimation.php)
# * [CGAL normal estimation using Jets](https://doc.cgal.org/latest/Jet_fitting_3/index.html#Jet_fitting_3Mathematical)
# * [DeepFit paper](https://arxiv.org/pdf/2003.10826.pdf)
# * [Jet fitting paper](https://graphics.stanford.edu/courses/cs468-03-fall/Papers/cazals_jets.pdf)
# * PCPNet and Dataset: http://geometry.cs.ucl.ac.uk/group_website/projects/2018/pcpnet/

# %% [markdown]
# ### Mathematical Background
# 3D point clouds are represented as a matrix of $(x, y, z)$ coordinates of points in 3D space.
# If you are unfamiliar with plane fitting and jets, this section provides a short background. For more in-depth information see the refrences at the bottom.
#
# The following methods share the following:
# * Input: 3D point cloud  + querry point $q_i$
# * Find $q_i$'s k nearest neighbors.
# * Do something fancey :)
# * Output: Normal vector at  query point $N_{q_i}$
#
# For estimating the normal at each point we use each point in the point cloud as the query point.
#
#
# #### PCA
# In this method we estimate the tangent plane to the underlying surface at the query point. This boils down to  solving the eigenvalue and eigenvector decomposition of the covariance matrix created from the points nearest neighbors:
#
# \begin{equation}
# C = \frac{1}{k}\sum_{i=1}^{k}(p_i-\hat{p})(p_i-\hat{p})^T
# \end{equation}
#
# Here $p_i$ are the neighboring points and $\hat{p}$ is the neighbours centroid.
# The normal vector is the eugenvector associated with the smallest eigenvalue.
#
# Using this method we cannot directly estimate the principal curvatures (the principal curvatures of a plane are 0).
#
#
# #### Jet fitting
#
#  An $n$-jet of the height function over a surface is given by:
#
# \begin{equation}
#     f(x,y)=J_{\beta,n}(x,y)= \sum_{k=0}^{n}\sum_{j=0}^{k}\beta_{k-j,j}x^{k-j}y^j
# \end{equation}
#
# Here $\beta$ is the jet coefficients vector that consists of $N_n=(n+1)(n+2)/2$ terms.
#
# We require that every point satisfy the equation above, yielding the system of linear equations:
# \begin{equation}
#     M\beta = B
# \end{equation}
#
# It is well known that the solution can be expressed in closed-form as:
# \begin{equation}
#     \beta = (M^TM)^{-1}M^TB
# \end{equation}
#
# Here $M=(1, x_i, y_i, ..., x_i y_i^{n-1}, y_i^n)_{i=1,...,N_p}\in \mathbb{R}^{N_p \times N_n}$ is the Vandermonde matrix and the height function vector $B=(z_1, z_2,...z_{N_p})^T \in \mathbb{R}^N_p$. Both represent the sampled points.

# %% [markdown]
# ### Import library for DeepFit utils

# %%
import sys  
import os
import numpy as np
sys.path.insert(0, '../DeepFit/utils')
sys.path.insert(0, '../DeepFit/models')
sys.path.insert(0, '../DeepFit/trained_models')

import DeepFit
import tutorial_utils as tu
import torch
import ipyvolume as ipv
import pylab
import ipywidgets as widgets
from IPython.display import display
import functools

# gpu_idx = 0
# device = torch.device("cpu" if gpu_idx < 0 else "cuda:%d" % 0)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.is_available():
    is_cuda = True
    print ("Using cuda (GPU) for training")
else:
    is_cuda = False
    print ("Using CPU")
# Out:
# Using cuda (GPU) for training

# %% [markdown]
# ### Import Data Paths

# %%
# Where to save the figures
PROJECT_ROOT_DIR = ".."
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "png_images")
DATA_PATH = os.path.join(PROJECT_ROOT_DIR, "dataset")
XYZ_point_PATH = os.path.join(DATA_PATH, "xyz")
file_output_dir =  os.path.join(PROJECT_ROOT_DIR, "output_dir/surface_fitting_result")
os.makedirs(IMAGES_PATH, exist_ok=True)
os.makedirs(file_output_dir, exist_ok=True)

## function for automatically save the diagram/graph into the folder 
def save_fig_plt(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
    
def save_fig_pylab (fig_name, tight_layout=True, fig_extension="png"):
    path = os.path.join(IMAGES_PATH, fig_name + "." + fig_extension)
    print("Saving figure ", fig_name)
    # if tight_layout:
    #     plt.tight_layout()
    ipv.pylab.savefig(path)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
# !nvidia-smi
# Out:
# Fri Jan 14 15:25:19 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 496.13       Driver Version: 496.13       CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   55C    P0    24W /  N/A |    121MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Generating dummy data
# Generate a synthetic example data for testing purpose. This way we have true ground truth parametric surface as reference for evaluating our results.

# %%
jet_order_data = 3
n_points = 4096
point_cloud_dataset = tu.SyntheticPointCloudDataset(n_points, jet_order_data, points_per_patch=128)
dataloader = torch.utils.data.DataLoader(point_cloud_dataset, batch_size=256, num_workers=8)

points = point_cloud_dataset.points
gt_normals = point_cloud_dataset.gt_normals

# %% [markdown]
# ### Normal estimation by "n-jet fitting" (n-order truncated Taylor expansion)

# %%
jet_order_fit = 3 # define jet order
for batchind, data in enumerate(dataloader):
    points, scale_radius = data[0], data[1]
    points = points.to(device) # to cuda processing 
    scale_radius = scale_radius.to(device)
    
    # compute jet coefficients and normal estimation
    pca_beta, n_est, _ = DeepFit.fit_Wjet(points, torch.ones_like(points[:, 0]), order=1,
                               compute_neighbor_normals=False)
    pca_normals = n_est if batchind==0 else torch.cat([pca_normals, n_est], 0)
    
    jet_beta, n_est, _ = DeepFit.fit_Wjet(points, torch.ones_like(points[:, 0]), order=jet_order_fit,
                               compute_neighbor_normals=False)
    jet_normals = n_est if batchind==0 else torch.cat([jet_normals, n_est], 0)
    
    # compute principal curvatures
    jet_curv_est, principal_dirs = tu.compute_principal_curvatures(jet_beta)
    jet_curv_est = jet_curv_est / scale_radius.unsqueeze(-1).repeat(1, jet_curv_est.shape[1])
    jet_curv_est = jet_curv_est.detach().cpu()
    jet_curvatures = jet_curv_est if batchind==0 else torch.cat([jet_curvatures, jet_curv_est], 0)

# %% [markdown]
# The normals are unoriented so we will now flip them upwards (assuming that the positive z axis points up)

# %%
n_sign = torch.sign(torch.sum(pca_normals*
                              torch.tensor([0., 0., 1.], device=pca_normals.device).repeat([n_points, 1]), dim=1)).unsqueeze(-1)
pca_normals = n_sign * pca_normals
pca_normals = pca_normals.detach().cpu().numpy()

n_sign = torch.sign(torch.sum(jet_normals*
                              torch.tensor([0., 0., 1.], device=jet_normals.device).repeat([n_points, 1]), dim=1)).unsqueeze(-1)
jet_normals = n_sign * jet_normals
jet_normals = jet_normals.detach().cpu().numpy()

# %% [markdown]
# ### Visualization

# %%
color_n_pca = tu.normal2rgb(pca_normals) #convert normal vectors to RGB
color_n_jet = tu.normal2rgb(jet_normals)
color_n_gt = tu.normal2rgb(gt_normals)

curvature_range_min = [-torch.mean(torch.abs(jet_curvatures[:, 1])) - torch.std(torch.abs(jet_curvatures[:, 1])), 
                                torch.mean(torch.abs(jet_curvatures[:, 1])) + torch.std(torch.abs(jet_curvatures[:, 1]))]
curvature_range_max = [-torch.mean(torch.abs(jet_curvatures[:, 0])) - torch.std(torch.abs(jet_curvatures[:, 0])), 
                                torch.mean(np.abs(jet_curvatures[:, 0])) + torch.std(torch.abs(jet_curvatures[:, 0]))]                                   
color_curv = tu.curvatures2rgb(jet_curvatures.clone(),  k1_range=curvature_range_max, k2_range=curvature_range_min)

# make some buttons to toggle between the colors 
btn_pca = widgets.Button(description='PCA')
btn_pca.style.button_color='lightgray'
btn_jet = widgets.Button(description='Jet')
btn_jet.style.button_color='lightgray'
btn_solid = widgets.Button(description='solid')
btn_solid.style.button_color='lightgray'
btn_gt = widgets.Button(description='GT')
btn_gt.style.button_color='lightgray'
btn_curv = widgets.Button(description='curvature')
btn_curv.style.button_color='lightgray'

def update_pc_normal_color(b, scatter_h):
    """    
        this function is linked to the buttons and updates the the point cloud color
    """
    if b.description == 'PCA':
        scatter_h.color = color_n_pca
    elif b.description == 'Jet': 
        scatter_h.color = color_n_jet
    elif b.description == 'solid':
        scatter_h.color = 'red'
    elif b.description == 'GT':
        scatter_h.color = color_n_gt
    elif b.description == 'curvature':
        scatter_h.color = color_curv


#plot
fig_h = ipv.figure()
scatter_h = ipv.pylab.scatter(point_cloud_dataset.points[:, 0], 
                              point_cloud_dataset.points[:, 1], 
                              point_cloud_dataset.points[:, 2], size=1, marker="sphere", color='red')
ipv.pylab.xyzlim(-1, 1)
ipv.style.use('minimal')
# button function 
btn_pca.on_click(functools.partial(update_pc_normal_color, scatter_h=scatter_h))
btn_jet.on_click(functools.partial(update_pc_normal_color, scatter_h=scatter_h))
btn_gt.on_click(functools.partial(update_pc_normal_color, scatter_h=scatter_h))
btn_solid.on_click(functools.partial(update_pc_normal_color, scatter_h=scatter_h))
btn_curv.on_click(functools.partial(update_pc_normal_color, scatter_h=scatter_h))

display(widgets.VBox((widgets.HBox((btn_pca, btn_jet, btn_gt, btn_solid, btn_curv)), fig_h)))
# Out:
# VBox(children=(HBox(children=(Button(description='PCA', style=ButtonStyle(button_color='lightgray')), Button(d…

# %% [markdown]
# ### Loading point cloud data of a AM part surface
#
# - **[Data Standarization]**: (SinglePointCloudDataset function) shrink the data to unit sphere (centered at zero, unit variance)

# %%
point_cloud_dataset = tu.SinglePointCloudDataset(os.path.join(XYZ_point_PATH, "22.xyz"), points_per_patch=256)
print(point_cloud_dataset.points)
# Out:
# [[-0.6779559  -0.6421214  -0.17365617]
#  [-0.6778716  -0.63878536 -0.17298028]
#  [-0.6777451  -0.6354909  -0.17281161]
#  ...
#  [ 0.7336731   0.6210594  -0.07588741]
#  [ 0.73396826  0.62448037 -0.0790126 ]
#  [ 0.73413754  0.6279013  -0.08040591]]

# %% [markdown]
# ### Fit an n-jet (and compute normal vector)
# This may take a while, depending on the number of points.
#
# Note: this is the classic jet fitting method which uses non-weighted least squares.

# %%
jet_order =3
dataloader = torch.utils.data.DataLoader(point_cloud_dataset, batch_size=256, num_workers=8)

for batchind, data in enumerate(dataloader, 0):
    points = data[0]
    data_trans = data[1]
    scale_radius = data[-1]
    points = points.to(device)
    data_trans = data_trans.to(device)
    scale_radius = scale_radius.to(device)
    
    beta, n_est, neighbors_n_est = DeepFit.fit_Wjet(points, torch.ones_like(points[:, 0]), order=jet_order,
                               compute_neighbor_normals=False)
    n_est = torch.bmm(n_est.unsqueeze(1), data_trans.transpose(2, 1)).squeeze(dim=1) # cancel out pca
    n_est = n_est.detach().cpu()
    normals = n_est if batchind==0 else torch.cat([normals, n_est], 0)
    
    curv_est, principal_dirs = tu.compute_principal_curvatures(beta)
    curv_est = curv_est / scale_radius.unsqueeze(-1).repeat(1, curv_est.shape[1])
    curv_est = curv_est.detach().cpu()
    curvatures = curv_est if batchind == 0 else torch.cat([curvatures, curv_est], 0)

# %% [markdown]
# The normals are unoriented so we will now flip them outwards (assuming that the origin is an internal point and the shape is simple)

# %%
n_sign = torch.sign(torch.sum(normals*torch.tensor(point_cloud_dataset.points), dim=1)).unsqueeze(-1)
normals = n_sign * normals
normals = normals.detach().cpu()
curvatures = n_sign.repeat([1, 2]) * curvatures

# %% [markdown]
# ### Visualize the point cloud (n-Jet fitting Results)
# We plot the point cloud and allow for 3 color overlays:
# * Solid - (all points have the same color)
# * Normals - We map the normal vectors to the RGB cube and use these values for coloring the point cloud.
# * Curvatures - We map the principal curvatures to the XXX colormap to RGB.

# %%
color_n = tu.normal2rgb(normals.numpy()) #convert normal vectors to RGB
curvature_range_min = [-torch.mean(torch.abs(curvatures[:, 1])) - torch.std(torch.abs(curvatures[:, 1])), 
                                torch.mean(torch.abs(curvatures[:, 1])) + torch.std(torch.abs(curvatures[:, 1]))]
curvature_range_max = [-torch.mean(torch.abs(curvatures[:, 0])) - torch.std(torch.abs(curvatures[:, 0])), 
                                torch.mean(np.abs(curvatures[:, 0])) + torch.std(torch.abs(curvatures[:, 0]))]                                   
color_curv = tu.curvatures2rgb(curvatures.clone(),  k1_range=curvature_range_max, k2_range=curvature_range_min)

# make some buttons to toggle between the colors 
btn_pc = widgets.Button(description='Solid')
btn_pc.style.button_color='lightgray'
btn_n = widgets.Button(description='normals')
btn_n.style.button_color='lightgray'
btn_c = widgets.Button(description='Curvatures')
btn_c.style.button_color='lightgray'

def update_pc_color_to_solid(b, scatter_h):
    """    
        this function is linked to the buttons and updates the the point cloud color
    """
    scatter_h.color = 'red'

    
def update_pc_color_to_normal(b, scatter_h):
    """    
        this function is linked to the buttons and updates the the point cloud color
    """
    scatter_h.color = color_n
    
def update_pc_color_to_curv(b, scatter_h):
    """    
        this function is linked to the buttons and updates the the point cloud color
    """
    scatter_h.color = color_curv

#plot
fig_h = ipv.figure()
scatter_h = ipv.pylab.scatter(point_cloud_dataset.points[:, 0], 
                              point_cloud_dataset.points[:, 1], 
                              point_cloud_dataset.points[:, 2], size=0.5, marker="sphere", color='red')
ipv.pylab.xyzlim(-1, 1)
ipv.style.use('minimal')
# ipv.show()

btn_pc.on_click(functools.partial(update_pc_color_to_solid, scatter_h=scatter_h))
btn_n.on_click(functools.partial(update_pc_color_to_normal, scatter_h=scatter_h))
btn_c.on_click(functools.partial(update_pc_color_to_curv, scatter_h=scatter_h))
out_widget = widgets.VBox((widgets.HBox((btn_pc, btn_n, btn_c)), fig_h))
display(out_widget)

# ipv.pylab.savefig("figure.png", fig = fig_h, output_widget= out_widget)

# create the colorbar
# cbar = ipv.pylab.colorbar(color_n)
# set the color of the lines
# cbar.solids.set_edgecolor("face")
# Out:
# VBox(children=(HBox(children=(Button(description='Solid', style=ButtonStyle(button_color='lightgray')), Button…

# %% [markdown]
# ### Fit an n-jet using DeepFit (and compute normal vector and principal curvatures)
# We first load the pretrained model and its parameters.

# %%
## clear cuda memory for unused variables
# torch.cuda.empty_cache()

# %%
trained_model_path = '../DeepFit/trained_models/DeepFit'
params = torch.load(os.path.join(trained_model_path, 'DeepFit_params.pth'))
k_neighbors = params.points_per_patch #note you can use a different number, this is what the network trained on
jet_order = params.jet_order
print('Using {} order jet for surface fitting'.format(jet_order))
model = DeepFit.DeepFit(k=1, num_points=k_neighbors, use_point_stn=params.use_point_stn,
                        use_feat_stn=params.use_feat_stn, point_tuple=params.point_tuple, sym_op=params.sym_op,
                        arch=params.arch, n_gaussians=params.n_gaussians, jet_order=jet_order,
                        weight_mode=params.weight_mode, use_consistency=False)
checkpoint = torch.load(os.path.join(trained_model_path, 'DeepFit.pth'))
model.load_state_dict(checkpoint)
model.to(device)
# Out:
# Using 3 order jet for surface fitting
# DeepFit(
#   (feat): PointNetEncoder(
#     (pointfeat): PointNetFeatures(
#       (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#       (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (stn1): QSTN(
#         (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#         (mp1): MaxPool1d(kernel_size=256, stride=256, padding=0, dilation=1, ceil_mode=False)
#         (fc1): Linear(in_features=1024, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=256, bias=True)
#         (fc3): Linear(in_features=256, out_features=4, bias=True)
#         (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stn2): STN(
#         (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#         (mp1): MaxPool1d(kernel_size=256, stride=256, padding=0, dilation=1, ceil_mode=False)
#         (fc1): Linear(in_features=1024, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=256, bias=True)
#         (fc3): Linear(in_features=256, out_features=4096, bias=True)
#         (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv1): Conv1d(1088, 512, kernel_size=(1,), stride=(1,))
#   (conv2): Conv1d(512, 256, kernel_size=(1,), stride=(1,))
#   (conv3): Conv1d(256, 128, kernel_size=(1,), stride=(1,))
#   (conv4): Conv1d(128, 1, kernel_size=(1,), stride=(1,))
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (do): Dropout(p=0.25, inplace=False)
# )

# %%
# torch.cuda.memory_summary(device=None, abbreviated=False)
# torch.cuda.memory_summary()

# %%
## clearing the occupied cuda memory 
## reference: https://stackoverflow.com/questions/59129812/how-to-avoid-cuda-out-of-memory-in-pytorch
# torch.cuda.empty_cache()

# import gc
# del variables
# gc.collect()

# %% [markdown]
# #### Next we use DeepFit to fit a surface at each point in the point cloud. (Use the pre-trained model)
# This may take a while, depending on the number of points.
#
# we also save the results into a txt file (.normal)

# %%
dataloader = torch.utils.data.DataLoader(point_cloud_dataset, batch_size=128, num_workers=8)

num_batch = len(dataloader)

for batchind, data in enumerate(dataloader, 0):
    points = data[0]
    data_trans = data[1]
    scale_radius = data[-1].squeeze()
    points = points.to(device)
    data_trans = data_trans.to(device)
    scale_radius = scale_radius.to(device)
    n_est, beta, weights, trans, trans2, neighbors_n_est = model.forward(points)
    if params.use_point_stn:
        n_est = torch.bmm(n_est.unsqueeze(1), trans.transpose(2, 1)).squeeze(dim=1) # cancel out poitnnet stn
    # transform predictions with inverse pca rotation (back to world space)
    n_est = torch.bmm(n_est.unsqueeze(1), data_trans.transpose(2, 1)).squeeze(dim=1)  # cancel out pca
    # print('batchind and batch number[%d/%d]' % (batchind, num_batch-1))

    n_est = n_est.detach().cpu()
    normals = n_est if batchind == 0 else torch.cat([normals, n_est], 0)
    # ---------------------------Save estimated normals to file --------------------------------
    # eps=1e-6
    # normals[np.logical_and(normals < eps, normals > -eps)] = 0.0
    np.savetxt(os.path.join(file_output_dir + '/22.normals'), normals)
    
    
    curv_est, principal_dirs = tu.compute_principal_curvatures(beta)
    curv_est = curv_est / scale_radius.unsqueeze(-1).repeat(1, curv_est.shape[1])
    curv_est = curv_est.detach().cpu()
    curvatures = curv_est if batchind == 0 else torch.cat([curvatures, curv_est], 0)
    
     # ---------------------------Save estimated normals to file --------------------------------
    np.savetxt(os.path.join(file_output_dir + '/22.curv'), curvatures)
# Out:
# catchind and batch number[0/1032]
# catchind and batch number[1/1032]
# catchind and batch number[2/1032]
# catchind and batch number[3/1032]
# catchind and batch number[4/1032]
# catchind and batch number[5/1032]
# catchind and batch number[6/1032]
# catchind and batch number[7/1032]
# catchind and batch number[8/1032]
# catchind and batch number[9/1032]
# catchind and batch number[10/1032]
# catchind and batch number[11/1032]
# catchind and batch number[12/1032]
# catchind and batch number[13/1032]
# catchind and batch number[14/1032]
# catchind and batch number[15/1032]
# catchind and batch number[16/1032]
# catchind and batch number[17/1032]
# catchind and batch number[18/1032]
# catchind and batch number[19/1032]
# catchind and batch number[20/1032]
# catchind and batch number[21/1032]
# catchind and batch number[22/1032]
# catchind and batch number[23/1032]
# catchind and batch number[24/1032]
# catchind and batch number[25/1032]
# catchind and batch number[26/1032]
# catchind and batch number[27/1032]
# catchind and batch number[28/1032]
# catchind and batch number[29/1032]
# catchind and batch number[30/1032]
# catchind and batch number[31/1032]
# catchind and batch number[32/1032]
# catchind and batch number[33/1032]
# catchind and batch number[34/1032]
# catchind and batch number[35/1032]
# catchind and batch number[36/1032]
# catchind and batch number[37/1032]
# catchind and batch number[38/1032]
# catchind and batch number[39/1032]
# catchind and batch number[40/1032]
# catchind and batch number[41/1032]
# catchind and batch number[42/1032]
# catchind and batch number[43/1032]
# catchind and batch number[44/1032]
# catchind and batch number[45/1032]
# catchind and batch number[46/1032]
# catchind and batch number[47/1032]
# catchind and batch number[48/1032]
# catchind and batch number[49/1032]
# catchind and batch number[50/1032]
# catchind and batch number[51/1032]
# catchind and batch number[52/1032]
# catchind and batch number[53/1032]
# catchind and batch number[54/1032]
# catchind and batch number[55/1032]
# catchind and batch number[56/1032]
# catchind and batch number[57/1032]
# catchind and batch number[58/1032]
# catchind and batch number[59/1032]
# catchind and batch number[60/1032]
# catchind and batch number[61/1032]
# catchind and batch number[62/1032]
# catchind and batch number[63/1032]
# catchind and batch number[64/1032]
# catchind and batch number[65/1032]
# catchind and batch number[66/1032]
# catchind and batch number[67/1032]
# catchind and batch number[68/1032]
# catchind and batch number[69/1032]
# catchind and batch number[70/1032]
# catchind and batch number[71/1032]
# catchind and batch number[72/1032]
# catchind and batch number[73/1032]
# catchind and batch number[74/1032]
# catchind and batch number[75/1032]
# catchind and batch number[76/1032]
# catchind and batch number[77/1032]
# catchind and batch number[78/1032]
# catchind and batch number[79/1032]
# catchind and batch number[80/1032]
# catchind and batch number[81/1032]
# catchind and batch number[82/1032]
# catchind and batch number[83/1032]
# catchind and batch number[84/1032]
# catchind and batch number[85/1032]
# catchind and batch number[86/1032]
# catchind and batch number[87/1032]
# catchind and batch number[88/1032]
# catchind and batch number[89/1032]
# catchind and batch number[90/1032]
# catchind and batch number[91/1032]
# catchind and batch number[92/1032]
# catchind and batch number[93/1032]
# catchind and batch number[94/1032]
# catchind and batch number[95/1032]
# catchind and batch number[96/1032]
# catchind and batch number[97/1032]
# catchind and batch number[98/1032]
# catchind and batch number[99/1032]
# catchind and batch number[100/1032]
# catchind and batch number[101/1032]
# catchind and batch number[102/1032]
# catchind and batch number[103/1032]
# catchind and batch number[104/1032]
# catchind and batch number[105/1032]
# catchind and batch number[106/1032]
# catchind and batch number[107/1032]
# catchind and batch number[108/1032]
# catchind and batch number[109/1032]
# catchind and batch number[110/1032]
# catchind and batch number[111/1032]
# catchind and batch number[112/1032]
# catchind and batch number[113/1032]
# catchind and batch number[114/1032]
# catchind and batch number[115/1032]
# catchind and batch number[116/1032]
# catchind and batch number[117/1032]
# catchind and batch number[118/1032]
# catchind and batch number[119/1032]
# catchind and batch number[120/1032]
# catchind and batch number[121/1032]
# catchind and batch number[122/1032]
# catchind and batch number[123/1032]
# catchind and batch number[124/1032]
# catchind and batch number[125/1032]
# catchind and batch number[126/1032]
# catchind and batch number[127/1032]
# catchind and batch number[128/1032]
# catchind and batch number[129/1032]
# catchind and batch number[130/1032]
# catchind and batch number[131/1032]
# catchind and batch number[132/1032]
# catchind and batch number[133/1032]
# catchind and batch number[134/1032]
# catchind and batch number[135/1032]
# catchind and batch number[136/1032]
# catchind and batch number[137/1032]
# catchind and batch number[138/1032]
# catchind and batch number[139/1032]
# catchind and batch number[140/1032]
# catchind and batch number[141/1032]
# catchind and batch number[142/1032]
# catchind and batch number[143/1032]
# catchind and batch number[144/1032]
# catchind and batch number[145/1032]
# catchind and batch number[146/1032]
# catchind and batch number[147/1032]
# catchind and batch number[148/1032]
# catchind and batch number[149/1032]
# catchind and batch number[150/1032]
# catchind and batch number[151/1032]
# catchind and batch number[152/1032]
# catchind and batch number[153/1032]
# catchind and batch number[154/1032]
# catchind and batch number[155/1032]
# catchind and batch number[156/1032]
# catchind and batch number[157/1032]
# catchind and batch number[158/1032]
# catchind and batch number[159/1032]
# catchind and batch number[160/1032]
# catchind and batch number[161/1032]
# catchind and batch number[162/1032]
# catchind and batch number[163/1032]
# catchind and batch number[164/1032]
# catchind and batch number[165/1032]
# catchind and batch number[166/1032]
# catchind and batch number[167/1032]
# catchind and batch number[168/1032]
# catchind and batch number[169/1032]
# catchind and batch number[170/1032]
# catchind and batch number[171/1032]
# catchind and batch number[172/1032]
# catchind and batch number[173/1032]
# catchind and batch number[174/1032]
# catchind and batch number[175/1032]
# catchind and batch number[176/1032]
# catchind and batch number[177/1032]
# catchind and batch number[178/1032]
# catchind and batch number[179/1032]
# catchind and batch number[180/1032]
# catchind and batch number[181/1032]
# catchind and batch number[182/1032]
# catchind and batch number[183/1032]
# catchind and batch number[184/1032]
# catchind and batch number[185/1032]
# catchind and batch number[186/1032]
# catchind and batch number[187/1032]
# catchind and batch number[188/1032]
# catchind and batch number[189/1032]
# catchind and batch number[190/1032]
# catchind and batch number[191/1032]
# catchind and batch number[192/1032]
# catchind and batch number[193/1032]
# catchind and batch number[194/1032]
# catchind and batch number[195/1032]
# catchind and batch number[196/1032]
# catchind and batch number[197/1032]
# catchind and batch number[198/1032]
# catchind and batch number[199/1032]
# catchind and batch number[200/1032]
# catchind and batch number[201/1032]
# catchind and batch number[202/1032]
# catchind and batch number[203/1032]
# catchind and batch number[204/1032]
# catchind and batch number[205/1032]
# catchind and batch number[206/1032]
# catchind and batch number[207/1032]
# catchind and batch number[208/1032]
# catchind and batch number[209/1032]
# catchind and batch number[210/1032]
# catchind and batch number[211/1032]
# catchind and batch number[212/1032]
# catchind and batch number[213/1032]
# catchind and batch number[214/1032]
# catchind and batch number[215/1032]
# catchind and batch number[216/1032]
# catchind and batch number[217/1032]
# catchind and batch number[218/1032]
# catchind and batch number[219/1032]
# catchind and batch number[220/1032]
# catchind and batch number[221/1032]
# catchind and batch number[222/1032]
# catchind and batch number[223/1032]
# catchind and batch number[224/1032]
# catchind and batch number[225/1032]
# catchind and batch number[226/1032]
# catchind and batch number[227/1032]
# catchind and batch number[228/1032]
# catchind and batch number[229/1032]
# catchind and batch number[230/1032]
# catchind and batch number[231/1032]
# catchind and batch number[232/1032]
# catchind and batch number[233/1032]
# catchind and batch number[234/1032]
# catchind and batch number[235/1032]
# catchind and batch number[236/1032]
# catchind and batch number[237/1032]
# catchind and batch number[238/1032]
# catchind and batch number[239/1032]
# catchind and batch number[240/1032]
# catchind and batch number[241/1032]
# catchind and batch number[242/1032]
# catchind and batch number[243/1032]
# catchind and batch number[244/1032]
# catchind and batch number[245/1032]
# catchind and batch number[246/1032]
# catchind and batch number[247/1032]
# catchind and batch number[248/1032]
# catchind and batch number[249/1032]
# catchind and batch number[250/1032]
# catchind and batch number[251/1032]
# catchind and batch number[252/1032]
# catchind and batch number[253/1032]
# catchind and batch number[254/1032]
# catchind and batch number[255/1032]
# catchind and batch number[256/1032]
# catchind and batch number[257/1032]
# catchind and batch number[258/1032]
# catchind and batch number[259/1032]
# catchind and batch number[260/1032]
# catchind and batch number[261/1032]
# catchind and batch number[262/1032]
# catchind and batch number[263/1032]
# catchind and batch number[264/1032]
# catchind and batch number[265/1032]
# catchind and batch number[266/1032]
# catchind and batch number[267/1032]
# catchind and batch number[268/1032]
# catchind and batch number[269/1032]
# catchind and batch number[270/1032]
# catchind and batch number[271/1032]
# catchind and batch number[272/1032]
# catchind and batch number[273/1032]
# catchind and batch number[274/1032]
# catchind and batch number[275/1032]
# catchind and batch number[276/1032]
# catchind and batch number[277/1032]
# catchind and batch number[278/1032]
# catchind and batch number[279/1032]
# catchind and batch number[280/1032]
# catchind and batch number[281/1032]
# catchind and batch number[282/1032]
# catchind and batch number[283/1032]
# catchind and batch number[284/1032]
# catchind and batch number[285/1032]
# catchind and batch number[286/1032]
# catchind and batch number[287/1032]
# catchind and batch number[288/1032]
# catchind and batch number[289/1032]
# catchind and batch number[290/1032]
# catchind and batch number[291/1032]
# catchind and batch number[292/1032]
# catchind and batch number[293/1032]
# catchind and batch number[294/1032]
# catchind and batch number[295/1032]
# catchind and batch number[296/1032]
# catchind and batch number[297/1032]
# catchind and batch number[298/1032]
# catchind and batch number[299/1032]
# catchind and batch number[300/1032]
# catchind and batch number[301/1032]
# catchind and batch number[302/1032]
# catchind and batch number[303/1032]
# catchind and batch number[304/1032]
# catchind and batch number[305/1032]
# catchind and batch number[306/1032]
# catchind and batch number[307/1032]
# catchind and batch number[308/1032]
# catchind and batch number[309/1032]
# catchind and batch number[310/1032]
# catchind and batch number[311/1032]
# catchind and batch number[312/1032]
# catchind and batch number[313/1032]
# catchind and batch number[314/1032]
# catchind and batch number[315/1032]
# catchind and batch number[316/1032]
# catchind and batch number[317/1032]
# catchind and batch number[318/1032]
# catchind and batch number[319/1032]
# catchind and batch number[320/1032]
# catchind and batch number[321/1032]
# catchind and batch number[322/1032]
# catchind and batch number[323/1032]
# catchind and batch number[324/1032]
# catchind and batch number[325/1032]
# catchind and batch number[326/1032]
# catchind and batch number[327/1032]
# catchind and batch number[328/1032]
# catchind and batch number[329/1032]
# catchind and batch number[330/1032]
# catchind and batch number[331/1032]
# catchind and batch number[332/1032]
# catchind and batch number[333/1032]
# catchind and batch number[334/1032]
# catchind and batch number[335/1032]
# catchind and batch number[336/1032]
# catchind and batch number[337/1032]
# catchind and batch number[338/1032]
# catchind and batch number[339/1032]
# catchind and batch number[340/1032]
# catchind and batch number[341/1032]
# catchind and batch number[342/1032]
# catchind and batch number[343/1032]
# catchind and batch number[344/1032]
# catchind and batch number[345/1032]
# catchind and batch number[346/1032]
# catchind and batch number[347/1032]
# catchind and batch number[348/1032]
# catchind and batch number[349/1032]
# catchind and batch number[350/1032]
# catchind and batch number[351/1032]
# catchind and batch number[352/1032]
# catchind and batch number[353/1032]
# catchind and batch number[354/1032]
# catchind and batch number[355/1032]
# catchind and batch number[356/1032]
# catchind and batch number[357/1032]
# catchind and batch number[358/1032]
# catchind and batch number[359/1032]
# catchind and batch number[360/1032]
# catchind and batch number[361/1032]
# catchind and batch number[362/1032]
# catchind and batch number[363/1032]
# catchind and batch number[364/1032]
# catchind and batch number[365/1032]
# catchind and batch number[366/1032]
# catchind and batch number[367/1032]
# catchind and batch number[368/1032]
# catchind and batch number[369/1032]
# catchind and batch number[370/1032]
# catchind and batch number[371/1032]
# catchind and batch number[372/1032]
# catchind and batch number[373/1032]
# catchind and batch number[374/1032]
# catchind and batch number[375/1032]
# catchind and batch number[376/1032]
# catchind and batch number[377/1032]
# catchind and batch number[378/1032]
# catchind and batch number[379/1032]
# catchind and batch number[380/1032]
# catchind and batch number[381/1032]
# catchind and batch number[382/1032]
# catchind and batch number[383/1032]
# catchind and batch number[384/1032]
# catchind and batch number[385/1032]
# catchind and batch number[386/1032]
# catchind and batch number[387/1032]
# catchind and batch number[388/1032]
# catchind and batch number[389/1032]
# catchind and batch number[390/1032]
# catchind and batch number[391/1032]
# catchind and batch number[392/1032]
# catchind and batch number[393/1032]
# catchind and batch number[394/1032]
# catchind and batch number[395/1032]
# catchind and batch number[396/1032]
# catchind and batch number[397/1032]
# catchind and batch number[398/1032]
# catchind and batch number[399/1032]
# catchind and batch number[400/1032]
# catchind and batch number[401/1032]
# catchind and batch number[402/1032]
# catchind and batch number[403/1032]
# catchind and batch number[404/1032]
# catchind and batch number[405/1032]
# catchind and batch number[406/1032]
# catchind and batch number[407/1032]
# catchind and batch number[408/1032]
# catchind and batch number[409/1032]
# catchind and batch number[410/1032]
# catchind and batch number[411/1032]
# catchind and batch number[412/1032]
# catchind and batch number[413/1032]
# catchind and batch number[414/1032]
# catchind and batch number[415/1032]
# catchind and batch number[416/1032]
# catchind and batch number[417/1032]
# catchind and batch number[418/1032]
# catchind and batch number[419/1032]
# catchind and batch number[420/1032]
# catchind and batch number[421/1032]
# catchind and batch number[422/1032]
# catchind and batch number[423/1032]
# catchind and batch number[424/1032]
# catchind and batch number[425/1032]
# catchind and batch number[426/1032]
# catchind and batch number[427/1032]
# catchind and batch number[428/1032]
# catchind and batch number[429/1032]
# catchind and batch number[430/1032]
# catchind and batch number[431/1032]
# catchind and batch number[432/1032]
# catchind and batch number[433/1032]
# catchind and batch number[434/1032]
# catchind and batch number[435/1032]
# catchind and batch number[436/1032]
# catchind and batch number[437/1032]
# catchind and batch number[438/1032]
# catchind and batch number[439/1032]
# catchind and batch number[440/1032]
# catchind and batch number[441/1032]
# catchind and batch number[442/1032]
# catchind and batch number[443/1032]
# catchind and batch number[444/1032]
# catchind and batch number[445/1032]
# catchind and batch number[446/1032]
# catchind and batch number[447/1032]
# catchind and batch number[448/1032]
# catchind and batch number[449/1032]
# catchind and batch number[450/1032]
# catchind and batch number[451/1032]
# catchind and batch number[452/1032]
# catchind and batch number[453/1032]
# catchind and batch number[454/1032]
# catchind and batch number[455/1032]
# catchind and batch number[456/1032]
# catchind and batch number[457/1032]
# catchind and batch number[458/1032]
# catchind and batch number[459/1032]
# catchind and batch number[460/1032]
# catchind and batch number[461/1032]
# catchind and batch number[462/1032]
# catchind and batch number[463/1032]
# catchind and batch number[464/1032]
# catchind and batch number[465/1032]
# catchind and batch number[466/1032]
# catchind and batch number[467/1032]
# catchind and batch number[468/1032]
# catchind and batch number[469/1032]
# catchind and batch number[470/1032]
# catchind and batch number[471/1032]
# catchind and batch number[472/1032]
# catchind and batch number[473/1032]
# catchind and batch number[474/1032]
# catchind and batch number[475/1032]
# catchind and batch number[476/1032]
# catchind and batch number[477/1032]
# catchind and batch number[478/1032]
# catchind and batch number[479/1032]
# catchind and batch number[480/1032]
# catchind and batch number[481/1032]
# catchind and batch number[482/1032]
# catchind and batch number[483/1032]
# catchind and batch number[484/1032]
# catchind and batch number[485/1032]
# catchind and batch number[486/1032]
# catchind and batch number[487/1032]
# catchind and batch number[488/1032]
# catchind and batch number[489/1032]
# catchind and batch number[490/1032]
# catchind and batch number[491/1032]
# catchind and batch number[492/1032]
# catchind and batch number[493/1032]
# catchind and batch number[494/1032]
# catchind and batch number[495/1032]
# catchind and batch number[496/1032]
# catchind and batch number[497/1032]
# catchind and batch number[498/1032]
# catchind and batch number[499/1032]
# catchind and batch number[500/1032]
# catchind and batch number[501/1032]
# catchind and batch number[502/1032]
# catchind and batch number[503/1032]
# catchind and batch number[504/1032]
# catchind and batch number[505/1032]
# catchind and batch number[506/1032]
# catchind and batch number[507/1032]
# catchind and batch number[508/1032]
# catchind and batch number[509/1032]
# catchind and batch number[510/1032]
# catchind and batch number[511/1032]
# catchind and batch number[512/1032]
# catchind and batch number[513/1032]
# catchind and batch number[514/1032]
# catchind and batch number[515/1032]
# catchind and batch number[516/1032]
# catchind and batch number[517/1032]
# catchind and batch number[518/1032]
# catchind and batch number[519/1032]
# catchind and batch number[520/1032]
# catchind and batch number[521/1032]
# catchind and batch number[522/1032]
# catchind and batch number[523/1032]
# catchind and batch number[524/1032]
# catchind and batch number[525/1032]
# catchind and batch number[526/1032]
# catchind and batch number[527/1032]
# catchind and batch number[528/1032]
# catchind and batch number[529/1032]
# catchind and batch number[530/1032]
# catchind and batch number[531/1032]
# catchind and batch number[532/1032]
# catchind and batch number[533/1032]
# catchind and batch number[534/1032]
# catchind and batch number[535/1032]
# catchind and batch number[536/1032]
# catchind and batch number[537/1032]
# catchind and batch number[538/1032]
# catchind and batch number[539/1032]
# catchind and batch number[540/1032]
# catchind and batch number[541/1032]
# catchind and batch number[542/1032]
# catchind and batch number[543/1032]
# catchind and batch number[544/1032]
# catchind and batch number[545/1032]
# catchind and batch number[546/1032]
# catchind and batch number[547/1032]
# catchind and batch number[548/1032]
# catchind and batch number[549/1032]
# catchind and batch number[550/1032]
# catchind and batch number[551/1032]
# catchind and batch number[552/1032]
# catchind and batch number[553/1032]
# catchind and batch number[554/1032]
# catchind and batch number[555/1032]
# catchind and batch number[556/1032]
# catchind and batch number[557/1032]
# catchind and batch number[558/1032]
# catchind and batch number[559/1032]
# catchind and batch number[560/1032]
# catchind and batch number[561/1032]
# catchind and batch number[562/1032]
# catchind and batch number[563/1032]
# catchind and batch number[564/1032]
# catchind and batch number[565/1032]
# catchind and batch number[566/1032]
# catchind and batch number[567/1032]
# catchind and batch number[568/1032]
# catchind and batch number[569/1032]
# catchind and batch number[570/1032]
# catchind and batch number[571/1032]
# catchind and batch number[572/1032]
# catchind and batch number[573/1032]
# catchind and batch number[574/1032]
# catchind and batch number[575/1032]
# catchind and batch number[576/1032]
# catchind and batch number[577/1032]
# catchind and batch number[578/1032]
# catchind and batch number[579/1032]
# catchind and batch number[580/1032]
# catchind and batch number[581/1032]
# catchind and batch number[582/1032]
# catchind and batch number[583/1032]
# catchind and batch number[584/1032]
# catchind and batch number[585/1032]
# catchind and batch number[586/1032]
# catchind and batch number[587/1032]
# catchind and batch number[588/1032]
# catchind and batch number[589/1032]
# catchind and batch number[590/1032]
# catchind and batch number[591/1032]
# catchind and batch number[592/1032]
# catchind and batch number[593/1032]
# catchind and batch number[594/1032]
# catchind and batch number[595/1032]
# catchind and batch number[596/1032]
# catchind and batch number[597/1032]
# catchind and batch number[598/1032]
# catchind and batch number[599/1032]
# catchind and batch number[600/1032]
# catchind and batch number[601/1032]
# catchind and batch number[602/1032]
# catchind and batch number[603/1032]
# catchind and batch number[604/1032]
# catchind and batch number[605/1032]
# catchind and batch number[606/1032]
# catchind and batch number[607/1032]
# catchind and batch number[608/1032]
# catchind and batch number[609/1032]
# catchind and batch number[610/1032]
# catchind and batch number[611/1032]
# catchind and batch number[612/1032]
# catchind and batch number[613/1032]
# catchind and batch number[614/1032]
# catchind and batch number[615/1032]
# catchind and batch number[616/1032]
# catchind and batch number[617/1032]
# catchind and batch number[618/1032]
# catchind and batch number[619/1032]
# catchind and batch number[620/1032]
# catchind and batch number[621/1032]
# catchind and batch number[622/1032]
# catchind and batch number[623/1032]
# catchind and batch number[624/1032]
# catchind and batch number[625/1032]
# catchind and batch number[626/1032]
# catchind and batch number[627/1032]
# catchind and batch number[628/1032]
# catchind and batch number[629/1032]
# catchind and batch number[630/1032]
# catchind and batch number[631/1032]
# catchind and batch number[632/1032]
# catchind and batch number[633/1032]
# catchind and batch number[634/1032]
# catchind and batch number[635/1032]
# catchind and batch number[636/1032]
# catchind and batch number[637/1032]
# catchind and batch number[638/1032]
# catchind and batch number[639/1032]
# catchind and batch number[640/1032]
# catchind and batch number[641/1032]
# catchind and batch number[642/1032]
# catchind and batch number[643/1032]
# catchind and batch number[644/1032]
# catchind and batch number[645/1032]
# catchind and batch number[646/1032]
# catchind and batch number[647/1032]
# catchind and batch number[648/1032]
# catchind and batch number[649/1032]
# catchind and batch number[650/1032]
# catchind and batch number[651/1032]
# catchind and batch number[652/1032]
# catchind and batch number[653/1032]
# catchind and batch number[654/1032]
# catchind and batch number[655/1032]
# catchind and batch number[656/1032]
# catchind and batch number[657/1032]
# catchind and batch number[658/1032]
# catchind and batch number[659/1032]
# catchind and batch number[660/1032]
# catchind and batch number[661/1032]
# catchind and batch number[662/1032]
# catchind and batch number[663/1032]
# catchind and batch number[664/1032]
# catchind and batch number[665/1032]
# catchind and batch number[666/1032]
# catchind and batch number[667/1032]
# catchind and batch number[668/1032]
# catchind and batch number[669/1032]
# catchind and batch number[670/1032]
# catchind and batch number[671/1032]
# catchind and batch number[672/1032]
# catchind and batch number[673/1032]
# catchind and batch number[674/1032]
# catchind and batch number[675/1032]
# catchind and batch number[676/1032]
# catchind and batch number[677/1032]
# catchind and batch number[678/1032]
# catchind and batch number[679/1032]
# catchind and batch number[680/1032]
# catchind and batch number[681/1032]
# catchind and batch number[682/1032]
# catchind and batch number[683/1032]
# catchind and batch number[684/1032]
# catchind and batch number[685/1032]
# catchind and batch number[686/1032]
# catchind and batch number[687/1032]
# catchind and batch number[688/1032]
# catchind and batch number[689/1032]
# catchind and batch number[690/1032]
# catchind and batch number[691/1032]
# catchind and batch number[692/1032]
# catchind and batch number[693/1032]
# catchind and batch number[694/1032]
# catchind and batch number[695/1032]
# catchind and batch number[696/1032]
# catchind and batch number[697/1032]
# catchind and batch number[698/1032]
# catchind and batch number[699/1032]
# catchind and batch number[700/1032]
# catchind and batch number[701/1032]
# catchind and batch number[702/1032]
# catchind and batch number[703/1032]
# catchind and batch number[704/1032]
# catchind and batch number[705/1032]
# catchind and batch number[706/1032]
# catchind and batch number[707/1032]
# catchind and batch number[708/1032]
# catchind and batch number[709/1032]
# catchind and batch number[710/1032]
# catchind and batch number[711/1032]
# catchind and batch number[712/1032]
# catchind and batch number[713/1032]
# catchind and batch number[714/1032]
# catchind and batch number[715/1032]
# catchind and batch number[716/1032]
# catchind and batch number[717/1032]
# catchind and batch number[718/1032]
# catchind and batch number[719/1032]
# catchind and batch number[720/1032]
# catchind and batch number[721/1032]
# catchind and batch number[722/1032]
# catchind and batch number[723/1032]
# catchind and batch number[724/1032]
# catchind and batch number[725/1032]
# catchind and batch number[726/1032]
# catchind and batch number[727/1032]
# catchind and batch number[728/1032]
# catchind and batch number[729/1032]
# catchind and batch number[730/1032]
# catchind and batch number[731/1032]
# catchind and batch number[732/1032]
# catchind and batch number[733/1032]
# catchind and batch number[734/1032]
# catchind and batch number[735/1032]
# catchind and batch number[736/1032]
# catchind and batch number[737/1032]
# catchind and batch number[738/1032]
# catchind and batch number[739/1032]
# catchind and batch number[740/1032]
# catchind and batch number[741/1032]
# catchind and batch number[742/1032]
# catchind and batch number[743/1032]
# catchind and batch number[744/1032]
# catchind and batch number[745/1032]
# catchind and batch number[746/1032]
# catchind and batch number[747/1032]
# catchind and batch number[748/1032]
# catchind and batch number[749/1032]
# catchind and batch number[750/1032]
# catchind and batch number[751/1032]
# catchind and batch number[752/1032]
# catchind and batch number[753/1032]
# catchind and batch number[754/1032]
# catchind and batch number[755/1032]
# catchind and batch number[756/1032]
# catchind and batch number[757/1032]
# catchind and batch number[758/1032]
# catchind and batch number[759/1032]
# catchind and batch number[760/1032]
# catchind and batch number[761/1032]
# catchind and batch number[762/1032]
# catchind and batch number[763/1032]
# catchind and batch number[764/1032]
# catchind and batch number[765/1032]
# catchind and batch number[766/1032]
# catchind and batch number[767/1032]
# catchind and batch number[768/1032]
# catchind and batch number[769/1032]
# catchind and batch number[770/1032]
# catchind and batch number[771/1032]
# catchind and batch number[772/1032]
# catchind and batch number[773/1032]
# catchind and batch number[774/1032]
# catchind and batch number[775/1032]
# catchind and batch number[776/1032]
# catchind and batch number[777/1032]
# catchind and batch number[778/1032]
# catchind and batch number[779/1032]
# catchind and batch number[780/1032]
# catchind and batch number[781/1032]
# catchind and batch number[782/1032]
# catchind and batch number[783/1032]
# catchind and batch number[784/1032]
# catchind and batch number[785/1032]
# catchind and batch number[786/1032]
# catchind and batch number[787/1032]
# catchind and batch number[788/1032]
# catchind and batch number[789/1032]
# catchind and batch number[790/1032]
# catchind and batch number[791/1032]
# catchind and batch number[792/1032]
# catchind and batch number[793/1032]
# catchind and batch number[794/1032]
# catchind and batch number[795/1032]
# catchind and batch number[796/1032]
# catchind and batch number[797/1032]
# catchind and batch number[798/1032]
# catchind and batch number[799/1032]
# catchind and batch number[800/1032]
# catchind and batch number[801/1032]
# catchind and batch number[802/1032]
# catchind and batch number[803/1032]
# catchind and batch number[804/1032]
# catchind and batch number[805/1032]
# catchind and batch number[806/1032]
# catchind and batch number[807/1032]
# catchind and batch number[808/1032]
# catchind and batch number[809/1032]
# catchind and batch number[810/1032]
# catchind and batch number[811/1032]
# catchind and batch number[812/1032]
# catchind and batch number[813/1032]
# catchind and batch number[814/1032]
# catchind and batch number[815/1032]
# catchind and batch number[816/1032]
# catchind and batch number[817/1032]
# catchind and batch number[818/1032]
# catchind and batch number[819/1032]
# catchind and batch number[820/1032]
# catchind and batch number[821/1032]
# catchind and batch number[822/1032]
# catchind and batch number[823/1032]
# catchind and batch number[824/1032]
# catchind and batch number[825/1032]
# catchind and batch number[826/1032]
# catchind and batch number[827/1032]
# catchind and batch number[828/1032]
# catchind and batch number[829/1032]
# catchind and batch number[830/1032]
# catchind and batch number[831/1032]
# catchind and batch number[832/1032]
# catchind and batch number[833/1032]
# catchind and batch number[834/1032]
# catchind and batch number[835/1032]
# catchind and batch number[836/1032]
# catchind and batch number[837/1032]
# catchind and batch number[838/1032]
# catchind and batch number[839/1032]
# catchind and batch number[840/1032]
# catchind and batch number[841/1032]
# catchind and batch number[842/1032]
# catchind and batch number[843/1032]
# catchind and batch number[844/1032]
# catchind and batch number[845/1032]
# catchind and batch number[846/1032]
# catchind and batch number[847/1032]
# catchind and batch number[848/1032]
# catchind and batch number[849/1032]
# catchind and batch number[850/1032]
# catchind and batch number[851/1032]
# catchind and batch number[852/1032]
# catchind and batch number[853/1032]
# catchind and batch number[854/1032]
# catchind and batch number[855/1032]
# catchind and batch number[856/1032]
# catchind and batch number[857/1032]
# catchind and batch number[858/1032]
# catchind and batch number[859/1032]
# catchind and batch number[860/1032]
# catchind and batch number[861/1032]
# catchind and batch number[862/1032]
# catchind and batch number[863/1032]
# catchind and batch number[864/1032]
# catchind and batch number[865/1032]
# catchind and batch number[866/1032]
# catchind and batch number[867/1032]
# catchind and batch number[868/1032]
# catchind and batch number[869/1032]
# catchind and batch number[870/1032]
# catchind and batch number[871/1032]
# catchind and batch number[872/1032]
# catchind and batch number[873/1032]
# catchind and batch number[874/1032]
# catchind and batch number[875/1032]
# catchind and batch number[876/1032]
# catchind and batch number[877/1032]
# catchind and batch number[878/1032]
# catchind and batch number[879/1032]
# catchind and batch number[880/1032]
# catchind and batch number[881/1032]
# catchind and batch number[882/1032]
# catchind and batch number[883/1032]
# catchind and batch number[884/1032]
# catchind and batch number[885/1032]
# catchind and batch number[886/1032]
# catchind and batch number[887/1032]
# catchind and batch number[888/1032]
# catchind and batch number[889/1032]
# catchind and batch number[890/1032]
# catchind and batch number[891/1032]
# catchind and batch number[892/1032]
# catchind and batch number[893/1032]
# catchind and batch number[894/1032]
# catchind and batch number[895/1032]
# catchind and batch number[896/1032]
# catchind and batch number[897/1032]
# catchind and batch number[898/1032]
# catchind and batch number[899/1032]
# catchind and batch number[900/1032]
# catchind and batch number[901/1032]
# catchind and batch number[902/1032]
# catchind and batch number[903/1032]
# catchind and batch number[904/1032]
# catchind and batch number[905/1032]
# catchind and batch number[906/1032]
# catchind and batch number[907/1032]
# catchind and batch number[908/1032]
# catchind and batch number[909/1032]
# catchind and batch number[910/1032]
# catchind and batch number[911/1032]
# catchind and batch number[912/1032]
# catchind and batch number[913/1032]
# catchind and batch number[914/1032]
# catchind and batch number[915/1032]
# catchind and batch number[916/1032]
# catchind and batch number[917/1032]
# catchind and batch number[918/1032]
# catchind and batch number[919/1032]
# catchind and batch number[920/1032]
# catchind and batch number[921/1032]
# catchind and batch number[922/1032]
# catchind and batch number[923/1032]
# catchind and batch number[924/1032]
# catchind and batch number[925/1032]
# catchind and batch number[926/1032]
# catchind and batch number[927/1032]
# catchind and batch number[928/1032]
# catchind and batch number[929/1032]
# catchind and batch number[930/1032]
# catchind and batch number[931/1032]
# catchind and batch number[932/1032]
# catchind and batch number[933/1032]
# catchind and batch number[934/1032]
# catchind and batch number[935/1032]
# catchind and batch number[936/1032]
# catchind and batch number[937/1032]
# catchind and batch number[938/1032]
# catchind and batch number[939/1032]
# catchind and batch number[940/1032]
# catchind and batch number[941/1032]
# catchind and batch number[942/1032]
# catchind and batch number[943/1032]
# catchind and batch number[944/1032]
# catchind and batch number[945/1032]
# catchind and batch number[946/1032]
# catchind and batch number[947/1032]
# catchind and batch number[948/1032]
# catchind and batch number[949/1032]
# catchind and batch number[950/1032]
# catchind and batch number[951/1032]
# catchind and batch number[952/1032]
# catchind and batch number[953/1032]
# catchind and batch number[954/1032]
# catchind and batch number[955/1032]
# catchind and batch number[956/1032]
# catchind and batch number[957/1032]
# catchind and batch number[958/1032]
# catchind and batch number[959/1032]
# catchind and batch number[960/1032]
# catchind and batch number[961/1032]
# catchind and batch number[962/1032]
# catchind and batch number[963/1032]
# catchind and batch number[964/1032]
# catchind and batch number[965/1032]
# catchind and batch number[966/1032]
# catchind and batch number[967/1032]
# catchind and batch number[968/1032]
# catchind and batch number[969/1032]
# catchind and batch number[970/1032]
# catchind and batch number[971/1032]
# catchind and batch number[972/1032]
# catchind and batch number[973/1032]
# catchind and batch number[974/1032]
# catchind and batch number[975/1032]
# catchind and batch number[976/1032]
# catchind and batch number[977/1032]
# catchind and batch number[978/1032]
# catchind and batch number[979/1032]
# catchind and batch number[980/1032]
# catchind and batch number[981/1032]
# catchind and batch number[982/1032]
# catchind and batch number[983/1032]
# catchind and batch number[984/1032]
# catchind and batch number[985/1032]
# catchind and batch number[986/1032]
# catchind and batch number[987/1032]
# catchind and batch number[988/1032]
# catchind and batch number[989/1032]
# catchind and batch number[990/1032]
# catchind and batch number[991/1032]
# catchind and batch number[992/1032]
# catchind and batch number[993/1032]
# catchind and batch number[994/1032]
# catchind and batch number[995/1032]
# catchind and batch number[996/1032]
# catchind and batch number[997/1032]
# catchind and batch number[998/1032]
# catchind and batch number[999/1032]
# catchind and batch number[1000/1032]
# catchind and batch number[1001/1032]
# catchind and batch number[1002/1032]
# catchind and batch number[1003/1032]
# catchind and batch number[1004/1032]
# catchind and batch number[1005/1032]
# catchind and batch number[1006/1032]
# catchind and batch number[1007/1032]
# catchind and batch number[1008/1032]
# catchind and batch number[1009/1032]
# catchind and batch number[1010/1032]
# catchind and batch number[1011/1032]
# catchind and batch number[1012/1032]
# catchind and batch number[1013/1032]
# catchind and batch number[1014/1032]
# catchind and batch number[1015/1032]
# catchind and batch number[1016/1032]
# catchind and batch number[1017/1032]
# catchind and batch number[1018/1032]
# catchind and batch number[1019/1032]
# catchind and batch number[1020/1032]
# catchind and batch number[1021/1032]
# catchind and batch number[1022/1032]
# catchind and batch number[1023/1032]
# catchind and batch number[1024/1032]
# catchind and batch number[1025/1032]
# catchind and batch number[1026/1032]
# catchind and batch number[1027/1032]
# catchind and batch number[1028/1032]
# catchind and batch number[1029/1032]
# catchind and batch number[1030/1032]
# catchind and batch number[1031/1032]
# catchind and batch number[1032/1032]

# %%
# ---------------------------Save estimated normals to file --------------------------------
#     batch_offset = 0
#     while batch_offset < n_est.shape[0] and shape_ind + 1 <= len(dataset.shape_names):
#         shape_patches_remaining = shape_patch_count - shape_patch_offset
#         batch_patches_remaining = n_est.shape[0] - batch_offset

#         # append estimated patch properties batch to properties for the current shape on the CPU
#         normal_prop[shape_patch_offset:shape_patch_offset + min(shape_patches_remaining,
#                                                                 batch_patches_remaining), :] = \
#             n_est[batch_offset:batch_offset + min(shape_patches_remaining, batch_patches_remaining), :]

#         batch_offset = batch_offset + min(shape_patches_remaining, batch_patches_remaining)
#         shape_patch_offset = shape_patch_offset + min(shape_patches_remaining, batch_patches_remaining)

#         if shape_patches_remaining <= batch_patches_remaining:
#             normals_to_write = normal_prop.cpu().numpy()
#             eps=1e-6
#             normals_to_write[np.logical_and(normals_to_write < eps, normals_to_write > -eps)] = 0.0
#             np.savetxt(os.path.join(output_dir, dataset.shape_names[shape_ind] + '.normals'),
#                        normals_to_write)


#             print('saved normals for ' + dataset.shape_names[shape_ind])
#             sys.stdout.flush()
#             shape_patch_offset = 0
#             shape_ind += 1
#             if shape_ind < len(dataset.shape_names):
#                 shape_patch_count = dataset.shape_patch_count[shape_ind]
#                 normal_prop = torch.zeros([shape_patch_count, 3])
# -----------------------------------------------------------------------------------------

# %% [markdown]
# The normals are unoriented so we will now flip them outwards (assuming that the origin is an internal point and the shape is simple)

# %%
n_sign = torch.sign(torch.sum(normals*torch.tensor(point_cloud_dataset.points), dim=1)).unsqueeze(-1)
normals = n_sign * normals
normals = normals.detach().cpu()
curvatures = n_sign.repeat([1, 2]) * curvatures

# %% [markdown]
# ### Visualize the point cloud (DeepFit Network results)
# We plot the point cloud and allow for 3 color overlays:
# * Solid - (all points have the same color)
# * Normals - We map the normal vectors to the RGB cube and use these values for coloring the point cloud.
# * Curvatures - We map the principal curvatures to the XXX colormap to RGB.

# %%
color_n = tu.normal2rgb(normals.numpy()) #convert normal vectors to RGB
curvature_range_min = [-torch.mean(torch.abs(curvatures[:, 1])) - torch.std(torch.abs(curvatures[:, 1])), 
                                torch.mean(torch.abs(curvatures[:, 1])) + torch.std(torch.abs(curvatures[:, 1]))]
curvature_range_max = [-torch.mean(torch.abs(curvatures[:, 0])) - torch.std(torch.abs(curvatures[:, 0])), 
                                torch.mean(np.abs(curvatures[:, 0])) + torch.std(torch.abs(curvatures[:, 0]))]                                   
color_curv = tu.curvatures2rgb(curvatures.clone(),  k1_range=curvature_range_max, k2_range=curvature_range_min)

# make some buttons to toggle between the colors 
btn_pc = widgets.Button(description='Solid')
btn_pc.style.button_color='lightgray'
btn_n = widgets.Button(description='normals')
btn_n.style.button_color='lightgray'
btn_c = widgets.Button(description='Curvatures')
btn_c.style.button_color='lightgray'

def update_pc_color_to_solid(b, scatter_h):
    """    
        this function is linked to the buttons and updates the the point cloud color
    """
    scatter_h.color = 'red'

    
def update_pc_color_to_normal(b, scatter_h):
    """    
        this function is linked to the buttons and updates the the point cloud color
    """
    scatter_h.color = color_n

def update_pc_color_to_curv(b, scatter_h):
    """    
        this function is linked to the buttons and updates the the point cloud color
    """
    scatter_h.color = color_curv

#plot
fig_h = ipv.figure()
scatter_h = ipv.pylab.scatter(point_cloud_dataset.points[:, 0], 
                              point_cloud_dataset.points[:, 1], 
                              point_cloud_dataset.points[:, 2], size=0.5, marker="sphere", color='red')
ipv.pylab.xyzlim(-1, 1)
ipv.style.use('minimal')
# ipv.show()

btn_pc.on_click(functools.partial(update_pc_color_to_solid, scatter_h=scatter_h))
btn_n.on_click(functools.partial(update_pc_color_to_normal, scatter_h=scatter_h))
btn_c.on_click(functools.partial(update_pc_color_to_curv, scatter_h=scatter_h))
display(widgets.VBox((widgets.HBox((btn_pc, btn_n, btn_c)), fig_h)))
# Out:
# VBox(children=(HBox(children=(Button(description='Solid', style=ButtonStyle(button_color='lightgray')), Button…

# %% [markdown]
# ## Performance evaluation and export results

# %% [markdown]
# - To test the model and output all normal estimations for the dataset run test_n_est.py. This will export the normal estimations for each file in the provided file list as a .normals file.
#
# - To evaluate the results and output a report run evaluate.py
#
# - To get all of the method's outputs exported (beta, weights, normals, curvatures) run test_c_est.py.
#
# - To evaluate curvature estimation performance run evaluate_curvatures.py (after exporting the results).

# %%
# !python "../DeepFit/evaluate_curvatures.py" --data_path "../dataset/xyz" --sparse_patches False --results_path "../DeepFit/trained_models/DeepFit/"
# Out:
# Traceback (most recent call last):
#   File "../DeepFit/evaluate_curvatures.py", line 62, in <module>
#     with open(curv_gt_filenames) as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Asus\\Github_repository\\AM_thermal_acoustic_defect_detection\\AM_Surface_Defect\\DeepFit\\../dataset/xyztestset_no_noise.txt'

# %%
# # load the data
# point_cloud_dataset = tu.SinglePointCloudDataset(os.path.join(XYZ_point_PATH, "22.xyz"), points_per_patch=256)

# points = np.loadtxt(os.path.join(XYZ_point_PATH, "22.xyz").astype('float32')
# curvatures_gt = np.loadtxt(os.path.join(file_output_dir, '22.curv')).astype('float32')
# curvatures_results = np.loadtxt(os.path.join(file_output_dir, '22.curv')).astype('float32')              
# # curvatures_results = np.loadtxt(os.path.join(curv_results_path, shape + '.curv')).astype('float32')
# # points_idx = np.loadtxt(os.path.join(curvatures_gt_path, shape + '.pidx')).astype('int')

# normals_gt = np.loadtxt(os.path.join(file_output_dir + '22.normals')).astype('float32')
# normals_results = np.loadtxt(os.path.join(file_output_dir + '22.normals')).astype('float32')                    
# # normals_results = np.loadtxt(os.path.join(curv_results_path, shape + '.normals')).astype('float32')

# # if os.path.exists(os.path.join(curv_results_path, shape + '.experts')):
# #     experts_exist = True
# #     experts = np.loadtxt(os.path.join(curv_results_path, shape + '.experts'))
# #     params = pickle.load(open(results_path + 'parameters.p', "rb"))
# #     n_experts = params.n_experts

# n_points = points.shape[0]
# n_curvatures = curvatures_results.shape[0]

# # if sparse_patches:
# #     points = points[points_idx, :]
# #     curvatures_gt = curvatures_gt[points_idx, :]
# #     normals_gt = normals_gt[points_idx, :]
# #     normals_results = normals_results[points_idx, :]

# if n_points != n_curvatures:
#     sparse_curvatures = True
# else:
#     sparse_curvatures = False

# # if sparse_patches and not sparse_curvatures:
# #     curvatures_results = curvatures_results[points_idx, :]


# # if (not sparse_patches) and sparse_curvatures:
# #     raise ValueError('Inconsistent sparse patches request - rerun test with sparse_patches set to False')

# # jet stored curvatures with an additional value - this is to remove it
# if curvatures_results.shape[1] > 2:
#     curvatures_results = curvatures_results[:, 0:2]

# # flip the sign according to the normal
# sign = np.sign(np.sum(normals_results * normals_gt, axis=1))
# curvatures_results = curvatures_results * np.tile(sign, [2, 1]).transpose()

# # if MAP_CURVATURES: #first column maximum, second minimum
# #     curvatures_results = map_curvatures(curvatures_results)  # for pcpnet


# # Not oriented rms
# diff_c = curvatures_results - curvatures_gt
# rms_regular_shape = np.sqrt(np.nanmean(np.square(diff_c), axis=0))
# true_rms_L_shape = np.sqrt(np.nanmean(np.square(diff_c/np.maximum(np.abs(curvatures_gt), np.ones_like(curvatures_gt))), axis=0))
# rms_L_shape = np.nanmean(np.abs((diff_c / np.maximum(np.abs(curvatures_gt), np.ones_like(curvatures_gt)))),
#                          axis=0)
# expanssion_coeff = 0.1
# rms_tanh_shape = np.sqrt(np.nanmean(
#     np.square(np.tanh(expanssion_coeff * curvatures_results) - np.tanh(expanssion_coeff * curvatures_gt)),
#     axis=0))

# # error metrics
# rms_regular.append(rms_regular_shape)
# true_rms_L.append(true_rms_L_shape)
# rms_L.append(rms_L_shape)
# rms_tanh.append(rms_tanh_shape)
